# %% [markdown]
# # Punto 1

# %%
import pandas as pd 
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("kc_house_data.csv")

# %%
# Análisis de los datos
data.describe()

# %%
pandas_profiling.ProfileReport(data)

# %%
#Ver valores ausentes 
data.isna().sum()
#No hay valores nulos

# %%
#Eliminar las columnas que no sirven como ID .... 
del data["id"]

# %%
#Crear una columna con los años en los que se realizó la venta
data["yearSold"] = data["date"].str[0:4]
del data["date"]
data.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
#Creo una nueva columna que el año en que se le realizó una modificación a la casa (Sea que se haya contruido o se haya remodelado)
data ["yearModified"] = data[["yr_built", "yr_renovated"]].apply(max, axis = 1)
del data["yr_built"]
del data["yr_renovated"]
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-31c11528a35c> in <module>
#       1 #Creo una nueva columna que el año en que se le realizó una modificación a la casa (Sea que se haya contruido o se haya remodelado)
# ----> 2 data ["yearModified"] = data[["yr_built", "yr_renovated"]].apply(max, axis = 1)
#       3 del data["yr_built"]
#       4 del data["yr_renovated"]
#       5 data.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...

# %%
#Crear una columna con la diferencia entre los años de venta y el año en que se construyó/remodelo (Vejez de la casa hasta cuando se vendió)
data.nunique()
# Out:
# id               21436
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# yearSold             2
# yearModified       116
# dtype: int64

# %%
data.count()-sum(data["yr_renovated"] == 0)

# %%
data.head(n=100)
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000  221900.0         3       1.00         1180
# 1   6414100192  20141209T000000  538000.0         3       2.25         2570
# 2   5631500400  20150225T000000  180000.0         2       1.00          770
# 3   2487200875  20141209T000000  604000.0         4       3.00         1960
# 4   1954400510  20150218T000000  510000.0         3       2.00         1680
# ..         ...              ...       ...       ...        ...          ...
# 95  1483300570  20140908T000000  905000.0         4       2.50         3300
# 96  3422049190  20150330T000000  247500.0         3       1.75         1960
# 97  1099611230  20140912T000000  199000.0         4       1.50         1160
# 98   722079104  20140711T000000  314000.0         3       1.75         1810
# 99  7338200240  20140516T000000  437500.0         3       2.50         2320
#
# ...
